# %%
import random
list_of_numbers = [random.randint(0, 10000) for _ in range(20000)]
print(list_of_numbers)
target_number = 3728
numbers = set()
target_sum = number_one + number_two
for num in target_sum:
    number_one = num
    number_two = target_number - num
    if num_two in numbers:
        print(f'Match found: {num_one} + {num_two}= target_number')
# Out:
# [2418, 7413, 9031, 3804, 2146, 9860, 4980, 306, 1906, 971, 9048, 1206, 1196, 3443, 8396, 4407, 5344, 4133, 7400, 4426, 1851, 2496, 2757, 1144, 8603, 7906, 5770, 1241, 2328, 6395, 5323, 635, 5734, 9453, 4678, 6563, 8062, 9164, 6902, 6205, 2989, 6839, 9613, 6200, 5553, 6615, 6010, 5415, 9035, 7965, 5408, 581, 8137, 2558, 2902, 204, 5571, 6147, 5501, 5580, 7571, 2921, 7070, 6869, 4454, 5877, 4488, 719, 3873, 324, 1747, 7908, 8719, 7802, 432, 940, 3626, 7099, 2766, 4618, 4797, 1029, 146, 3527, 6225, 8928, 4397, 681, 8134, 326, 3098, 1483, 8244, 4372, 5463, 3863, 5749, 9362, 6924, 3185, 7642, 8633, 179, 9582, 3607, 393, 2974, 8131, 4319, 9684, 1281, 2641, 3117, 8585, 5504, 5449, 110, 7963, 4752, 1549, 3219, 7965, 1427, 8744, 3502, 8949, 6005, 9010, 8635, 992, 1977, 4654, 2109, 4080, 6505, 4332, 3741, 7055, 3863, 501, 5348, 4527, 1523, 1846, 2896, 8978, 4129, 9954, 140, 480, 9452, 6932, 2953, 8009, 2018, 2920, 5134, 8170, 1852, 2130, 3244, 2324, 3316, 2590, 725, 5994, 7220, 5927, 6759, 449
# ...

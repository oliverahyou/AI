# %% [markdown]
# # **Data Preprocessing**

# %% [markdown]
# **Initial Exploratory Data Analysis**

# %% [markdown]
# Loading dataset

# %%
import pandas as pd
df = pd.read_csv('../data/raw/feedback_data.csv')

# %% [markdown]
# Dataset Inspection

# %%
df.head()
# Out:
#    RespondentID                                           Feedback
# 0             1  Taste is nice but it's a bit pricey. Hope you ...
# 1             2  My morning feels incomplete without it. Custom...
# 2             3            Love this coffee. Not bad at all tbh. 👎
# 3             4                                  Expected better 👍
# 4             5                               Worth every penny. 😕

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   RespondentID  1500 non-null   int64
#  1   Feedback      1500 non-null   str
# dtypes: int64(1), str(1)
# memory usage: 97.7 KB

# %%
df.describe()
# Out:
#        RespondentID
# count   1500.000000
# mean     750.500000
# std      433.157015
# min        1.000000
# 25%      375.750000
# 50%      750.500000
# 75%     1125.250000
# max     1500.000000

# %%
df.isnull().sum()
# Out:
# RespondentID    0
# Feedback        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Rows: 1500
# Columns: 2
# Missing values: None
# Duplicated values: None
#
# Since no missing or duplicated values, no cleaning via 'drop' required.

# %% [markdown]
# **Text Cleaning**
#
# * Lowercasing
# * Removing URLs
# * Removing HTML
# * Removing emojis
# * Removing punctiations
# * Removing numbers
# * Removing extra spacing
# * Expanding abbreviations

# %%
import re
import string
import emoji

slang_dict = {
    "ngl": "honestly", #tokenizing not gonna lie >>>'not gon na lie' then lemmmatizing would result in loss of information
    "tbh": "honestly",#similarly here, so a single word summary is used instead
    "imo": "opinion",
    "idk": "unknown"
}

def expand_slang(text):
    for word, replacement in slang_dict.items():
        text = re.sub(
            rf"\b{word}\b",
            replacement,
            text
        )
    return text

def clean_text(text):
    # Lowercasing
    text = text.lower()

    # Remove URLs
    text = re.sub(r"http\S+|www\S+", "", text)

    # Remove HTML
    text = re.sub(r"<.*?>", "", text)

    # Remove emojis
    text = emoji.replace_emoji(text, replace="")

    # Remove punctuation
    text = text.translate(
        str.maketrans("", "", string.punctuation)
    )

    # Remove numbers
    text = re.sub(r"\d+", "", text)

    # Remove extra whitespace
    text = re.sub(r"\s+", " ", text)
    text = text.strip()

    return text

# %%
df["clean_feedback"] = (
    df["Feedback"]
    .apply(expand_slang)
    .apply(clean_text)
)

# %%
df.head(100)
# Out:
#     RespondentID                                           Feedback  \
# 0              1  Taste is nice but it's a bit pricey. Hope you ...
# 1              2  My morning feels incomplete without it. Custom...
# 2              3            Love this coffee. Not bad at all tbh. 👎
# 3              4                                  Expected better 👍
# 4              5                               Worth every penny. 😕
# ..           ...                                                ...
# 95            96   Amazing aroma. Would recommend it to friends. ❤️
# 96            97            Way too expensive. ngl I expected more.
# 97            98  Works gr8 with milk but black coffee isn't my ...
# 98            99  Best coffee I've had in a while. ngl I expecte...
# 99           100                                         Not bad. ☕
#
#                                        clean_feedback
# 0   taste is nice but its a bit pricey hope you ke...
# 1   my morning feels incomplete without it custome...
# 2            love this coffee not bad at all honestly
# 3                                     expected better
# 4                                   worth every penny
# ..                                                ...
# 95        amazing aroma would recommend it to friends
# 96         way too expensive honestly i expected more
# 97  works gr with milk but black coffee isnt my fa...
# 98  best coffee ive had in a while honestly i expe...
# 99                                            not bad
#
# [100 rows x 3 columns]

# %%
df.to_csv(
    "../data/processed/clean_feedback_data.csv",
    index=False
)

# %% [markdown]
# Feedback
#
# clean_feedback_data
#     ↓
# Tokenization
#     ↓
# Stopword removal
#     ↓
# Lemmatization
#     ↓
# TF-IDF
#     ↓
# Sentiment Model

# %% [markdown]
# **NLP Preprocessing**
#
# * Tokenization
# * Stopword removal
# * Lemmetization

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

nltk.download("stopwords")
nltk.download("punkt")
nltk.download("wordnet")
nltk.download("omw-1.4")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\kowoy\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\kowoy\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\kowoy\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\kowoy\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
#Loading new cleaned dataset
df = pd.read_csv('../data/processed/clean_feedback_data.csv')

# %%
df["clean_feedback"].isna().sum()

df = df.dropna(subset=["clean_feedback"])

df = df[df["clean_feedback"].str.strip() != ""]

# %%
#Tokenization
df["tokens"] = df["clean_feedback"].apply(word_tokenize)
df.head(100)
# Out:
#     RespondentID                                           Feedback  \
# 0              1  Taste is nice but it's a bit pricey. Hope you ...
# 1              2  My morning feels incomplete without it. Custom...
# 2              3            Love this coffee. Not bad at all tbh. 👎
# 3              4                                  Expected better 👍
# 4              5                               Worth every penny. 😕
# ..           ...                                                ...
# 95            96   Amazing aroma. Would recommend it to friends. ❤️
# 96            97            Way too expensive. ngl I expected more.
# 97            98  Works gr8 with milk but black coffee isn't my ...
# 98            99  Best coffee I've had in a while. ngl I expecte...
# 99           100                                         Not bad. ☕
#
#                                        clean_feedback  \
# 0   taste is nice but its a bit pricey hope you ke...
# 1   my morning feels incomplete without it custome...
# 2            love this coffee not bad at all honestly
# 3                                     expected better
# 4                                   worth every penny
# ..                                                ...
# 95        amazing aroma would recommend it to friends
# 96         way too expensive honestly i expected more
# 97  works gr with milk but black coffee isnt my fa...
# 98  best coffee ive had in a while honestly i expe...
# 99                                            not bad
#
#                                                tokens
# 0   [taste, is, nice, but, its, a, bit, pricey, ho...
# 1   [my, morning, feels, incomplete, without, it, ...
# 2   [love, this, coffee, not, bad, at, all, honestly]
# 3                                  [expected, better]
# 4                               [worth, every, penny]
# ..                                                ...
# 95  [amazing, aroma, would, recommend, it, to, fri...
# 96  [way, too, expensive, honestly, i, expected, m...
# 97  [works, gr, with, milk, but, black, coffee, is...
# 98  [best, coffee, ive, had, in, a, while, honestl...
# 99                                         [not, bad]
#
# [100 rows x 4 columns]

# %%
#Stopword removal
#Creating stopword list
stop_words = set(stopwords.words("english"))

#Keeping relevant sentiment words
stop_words = stop_words - {
    "not",
    "no",
    "nor",
    "never"
}

#Creating stopword removal function
def remove_stopwords(tokens):

    filtered_tokens = [
        word for word in tokens
        if word.lower() not in stop_words
    ]

    return filtered_tokens

#Apply stopword removal function within new column 'filtered_tokens'
df["filtered_tokens"] = df["tokens"].apply(remove_stopwords)

# %%
df.head(100)
# Out:
#     RespondentID                                           Feedback  \
# 0              1  Taste is nice but it's a bit pricey. Hope you ...
# 1              2  My morning feels incomplete without it. Custom...
# 2              3            Love this coffee. Not bad at all tbh. 👎
# 3              4                                  Expected better 👍
# 4              5                               Worth every penny. 😕
# ..           ...                                                ...
# 95            96   Amazing aroma. Would recommend it to friends. ❤️
# 96            97            Way too expensive. ngl I expected more.
# 97            98  Works gr8 with milk but black coffee isn't my ...
# 98            99  Best coffee I've had in a while. ngl I expecte...
# 99           100                                         Not bad. ☕
#
#                                        clean_feedback  \
# 0   taste is nice but its a bit pricey hope you ke...
# 1   my morning feels incomplete without it custome...
# 2            love this coffee not bad at all honestly
# 3                                     expected better
# 4                                   worth every penny
# ..                                                ...
# 95        amazing aroma would recommend it to friends
# 96         way too expensive honestly i expected more
# 97  works gr with milk but black coffee isnt my fa...
# 98  best coffee ive had in a while honestly i expe...
# 99                                            not bad
#
#                                                tokens  \
# 0   [taste, is, nice, but, its, a, bit, pricey, ho...
# 1   [my, morning, feels, incomplete, without, it, ...
# 2   [love, this, coffee, not, bad, at, all, honestly]
# 3                                  [expected, better]
# 4                               [worth, every, penny]
# ..                                                ...
# 95  [amazing, aroma, would, recommend, it, to, fri...
# 96  [way, too, expensive, honestly, i, expected, m...
# 97  [works, gr, with, milk, but, black, coffee, is...
# 98  [best, coffee, ive, had, in, a, while, honestl...
# 99                                         [not, bad]
#
#                                       filtered_tokens
# 0   [taste, nice, bit, pricey, hope, keep, quality...
# 1   [morning, feels, incomplete, without, customer...
# 2                  [love, coffee, not, bad, honestly]
# 3                                  [expected, better]
# 4                               [worth, every, penny]
# ..                                                ...
# 95        [amazing, aroma, would, recommend, friends]
# 96               [way, expensive, honestly, expected]
# 97  [works, gr, milk, black, coffee, isnt, favourite]
# 98            [best, coffee, ive, honestly, expected]
# 99                                         [not, bad]
#
# [100 rows x 5 columns]

# %%
#Create lemmatizer
lemmatizer = WordNetLemmatizer()
#Create lemmatizer function
def lemmatize_tokens(tokens):
    lemmatized = [
        lemmatizer.lemmatize(word)
        for word in tokens
    ]
    return lemmatized

df["lemmatized_tokens"] = df["filtered_tokens"].apply(lemmatize_tokens)

# %%
df.head(100)
# Out:
#     RespondentID                                           Feedback  \
# 0              1  Taste is nice but it's a bit pricey. Hope you ...
# 1              2  My morning feels incomplete without it. Custom...
# 2              3            Love this coffee. Not bad at all tbh. 👎
# 3              4                                  Expected better 👍
# 4              5                               Worth every penny. 😕
# ..           ...                                                ...
# 95            96   Amazing aroma. Would recommend it to friends. ❤️
# 96            97            Way too expensive. ngl I expected more.
# 97            98  Works gr8 with milk but black coffee isn't my ...
# 98            99  Best coffee I've had in a while. ngl I expecte...
# 99           100                                         Not bad. ☕
#
#                                        clean_feedback  \
# 0   taste is nice but its a bit pricey hope you ke...
# 1   my morning feels incomplete without it custome...
# 2            love this coffee not bad at all honestly
# 3                                     expected better
# 4                                   worth every penny
# ..                                                ...
# 95        amazing aroma would recommend it to friends
# 96         way too expensive honestly i expected more
# 97  works gr with milk but black coffee isnt my fa...
# 98  best coffee ive had in a while honestly i expe...
# 99                                            not bad
#
#                                                tokens  \
# 0   [taste, is, nice, but, its, a, bit, pricey, ho...
# 1   [my, morning, feels, incomplete, without, it, ...
# 2   [love, this, coffee, not, bad, at, all, honestly]
# 3                                  [expected, better]
# 4                               [worth, every, penny]
# ..                                                ...
# 95  [amazing, aroma, would, recommend, it, to, fri...
# 96  [way, too, expensive, honestly, i, expected, m...
# 97  [works, gr, with, milk, but, black, coffee, is...
# 98  [best, coffee, ive, had, in, a, while, honestl...
# 99                                         [not, bad]
#
#                                       filtered_tokens  \
# 0   [taste, nice, bit, pricey, hope, keep, quality...
# 1   [morning, feels, incomplete, without, customer...
# 2                  [love, coffee, not, bad, honestly]
# 3                                  [expected, better]
# 4                               [worth, every, penny]
# ..                                                ...
# 95        [amazing, aroma, would, recommend, friends]
# 96               [way, expensive, honestly, expected]
# 97  [works, gr, milk, black, coffee, isnt, favourite]
# 98            [best, coffee, ive, honestly, expected]
# 99                                         [not, bad]
#
#                                     lemmatized_tokens
# 0   [taste, nice, bit, pricey, hope, keep, quality...
# 1   [morning, feel, incomplete, without, customer,...
# 2                  [love, coffee, not, bad, honestly]
# 3                                  [expected, better]
# 4                               [worth, every, penny]
# ..                                                ...
# 95         [amazing, aroma, would, recommend, friend]
# 96               [way, expensive, honestly, expected]
# 97   [work, gr, milk, black, coffee, isnt, favourite]
# 98            [best, coffee, ive, honestly, expected]
# 99                                         [not, bad]
#
# [100 rows x 6 columns]

# %%
#Final column creation where lemmatized tokens are joined into a single string
df["processed_text"] = df["lemmatized_tokens"].apply(
    lambda x: " ".join(x)
)
df.head(100)
# Out:
#     RespondentID                                           Feedback  \
# 0              1  Taste is nice but it's a bit pricey. Hope you ...
# 1              2  My morning feels incomplete without it. Custom...
# 2              3            Love this coffee. Not bad at all tbh. 👎
# 3              4                                  Expected better 👍
# 4              5                               Worth every penny. 😕
# ..           ...                                                ...
# 95            96   Amazing aroma. Would recommend it to friends. ❤️
# 96            97            Way too expensive. ngl I expected more.
# 97            98  Works gr8 with milk but black coffee isn't my ...
# 98            99  Best coffee I've had in a while. ngl I expecte...
# 99           100                                         Not bad. ☕
#
#                                        clean_feedback  \
# 0   taste is nice but its a bit pricey hope you ke...
# 1   my morning feels incomplete without it custome...
# 2            love this coffee not bad at all honestly
# 3                                     expected better
# 4                                   worth every penny
# ..                                                ...
# 95        amazing aroma would recommend it to friends
# 96         way too expensive honestly i expected more
# 97  works gr with milk but black coffee isnt my fa...
# 98  best coffee ive had in a while honestly i expe...
# 99                                            not bad
#
#                                                tokens  \
# 0   [taste, is, nice, but, its, a, bit, pricey, ho...
# 1   [my, morning, feels, incomplete, without, it, ...
# 2   [love, this, coffee, not, bad, at, all, honestly]
# 3                                  [expected, better]
# 4                               [worth, every, penny]
# ..                                                ...
# 95  [amazing, aroma, would, recommend, it, to, fri...
# 96  [way, too, expensive, honestly, i, expected, m...
# 97  [works, gr, with, milk, but, black, coffee, is...
# 98  [best, coffee, ive, had, in, a, while, honestl...
# 99                                         [not, bad]
#
#                                       filtered_tokens  \
# 0   [taste, nice, bit, pricey, hope, keep, quality...
# 1   [morning, feels, incomplete, without, customer...
# 2                  [love, coffee, not, bad, honestly]
# 3                                  [expected, better]
# 4                               [worth, every, penny]
# ..                                                ...
# 95        [amazing, aroma, would, recommend, friends]
# 96               [way, expensive, honestly, expected]
# 97  [works, gr, milk, black, coffee, isnt, favourite]
# 98            [best, coffee, ive, honestly, expected]
# 99                                         [not, bad]
#
#                                     lemmatized_tokens  \
# 0   [taste, nice, bit, pricey, hope, keep, quality...
# 1   [morning, feel, incomplete, without, customer,...
# 2                  [love, coffee, not, bad, honestly]
# 3                                  [expected, better]
# 4                               [worth, every, penny]
# ..                                                ...
# 95         [amazing, aroma, would, recommend, friend]
# 96               [way, expensive, honestly, expected]
# 97   [work, gr, milk, black, coffee, isnt, favourite]
# 98            [best, coffee, ive, honestly, expected]
# 99                                         [not, bad]
#
#                                        processed_text
# 0   taste nice bit pricey hope keep quality consis...
# 1   morning feel incomplete without customer servi...
# 2                        love coffee not bad honestly
# 3                                     expected better
# 4                                   worth every penny
# ..                                                ...
# 95               amazing aroma would recommend friend
# 96                    way expensive honestly expected
# 97           work gr milk black coffee isnt favourite
# 98                  best coffee ive honestly expected
# 99                                            not bad
#
# [100 rows x 7 columns]
